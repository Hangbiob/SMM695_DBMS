# %%
import os, glob
import pickle

folder = '.bugs/'

for f in glob.glob(os.path.join(folder, '*pickle')):
    d = pickle.load(open(f, 'rb'))
    break

# %%
d
# Out:
# {'cf_tracking_thunderbird_esr115': '---',
#  'type': 'defect',
#  'cf_status_thunderbird_esr91': '---',
#  'flags': [],
#  'cf_status_thunderbird_esr102': '---',
#  'classification': 'Components',
#  'summary': 'Table is laid out incorrectly',
#  'cf_has_str': '---',
#  'cf_tracking_firefox_esr102': '---',
#  'cf_tracking_thunderbird_esr91': '---',
#  'depends_on': [],
#  'whiteboard': '',
#  'creator': 'phil@rebee.clara.co.uk',
#  'qa_contact': 'amar@formerly-netscape.com.tld',
#  'creation_time': <DateTime '20010803T12:26:24' at 0x7fb4d07abdc0>,
#  'cf_a11y_review_project_flag': '---',
#  'last_change_time': <DateTime '20011006T22:54:12' at 0x7fb4d07aa590>,
#  'regressions': [],
#  'id': 93396,
#  'cf_last_resolved': <DateTime '20011006T22:54:12' at 0x7fb4d07a9150>,
#  'cf_status_firefox116': '---',
#  'op_sys': 'All',
#  'cf_status_thunderbird_esr115': '---',
#  'cf_webcompat_priority': '---',
#  'regressed_by': [],
#  'cf_tracking_firefox116': '---',
# ...
